# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import re, pathlib, string
from datetime import datetime

# %%
def segment_hashtag(hashtag):
    if hashtag.startswith('#'):
        hashtag = hashtag[1:]
    
    words = []
    current_word = hashtag[0].lower()
    
    for char in hashtag[1:]:
        if char.isupper():
            words.append(current_word)
            current_word = char.lower()
        else:
            current_word += char.lower()
    
    words.append(current_word)
    return words

def segment_hashtags_in_tweet(tweet):
    def replace_hashtag(match):
        hashtag = match.group(0)
        segmented = segment_hashtag(hashtag)
        return ' '.join(segmented)
    
    segmented_tweet = re.sub(r'#\w+', replace_hashtag, tweet)
    
    return segmented_tweet

# %%
def remove_offset(timestamp: str) -> str:
    # Convert to datetime object and remove the offset
    dt = datetime.fromisoformat(timestamp).replace(tzinfo=None)
    
    # Convert back to string without offset
    return dt.strftime("%Y-%m-%d %H:%M:%S")

def convert_tweet_date(date_string):
    date_string = date_string.strip()
    
    # Try different format strings
    formats = [
        "%I:%M:%S %p · %b %d, %Y",
        "%I:%M %p · %b %d, %Y",
        "%I:%M:%S %p · %b %d, %Y",
        "%I:%M %p · %B %d, %Y",  # Full month name
        "%H:%M:%S · %b %d, %Y",  # 24-hour format
        "%H:%M · %b %d, %Y",     # 24-hour format without seconds
    ]
    
    for fmt in formats:
        try:
            dt = datetime.strptime(date_string, fmt)
            print(f"Successful format: {fmt}")
            return dt
        except ValueError as e:
            print(f"Failed format: {fmt}")
            print(f"Error: {e}")
    
    raise ValueError(f"Unable to parse date string: {date_string}")

# %%
def clean_tweet(tweet): # If that fails, try parsing without seconds
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    tweet = re.sub(r'http\S+|www\S+|https\S+', '', tweet, flags=re.MULTILINE)
    
    tweet = tweet.encode('ascii', 'ignore').decode('ascii')

    tweet = re.sub(r'@\w+', '', tweet)
    
    emoticon_pattern = r'[:;=][oO\-]?[D\)\]\(\]/\\OpP]'
    tweet = re.sub(emoticon_pattern, '', tweet)
    
    tweet = segment_hashtags_in_tweet(tweet)

    return tweet

# %%
def trim_spaces_in_middle(text):
    trimmed_text = ' '.join(text.split())
    return trimmed_text

# %%
  
language = input('Language: ')
if language == 'en':
    dataset_path_input = "../dataset/english_gold_standard.csv"
    dataset_path_output = "../dataset/cleaned_english_tweets.csv"
elif language == 'it':
    dataset_path_input =  "../dataset/italian_gold_standard.csv"
    dataset_path_output = "../dataset/cleaned_italian_tweets.csv"
else:
    print("Language doesn't recognize")


df = pd.read_csv(dataset_path_input, sep=';')
df['cleaned_tweets'] = df['text'].apply(clean_tweet)
df['cleaned_tweets'] = df['cleaned_tweets'].apply(trim_spaces_in_middle)

    
df.drop(['text','Unnamed: 0'], axis=1, inplace=True)
if language == 'it':
    df['date'] = df['date'].apply(convert_tweet_date)c
elif language == 'en':
    df['date'] = df['date'].apply(remove_offset)
    
        
df.to_csv(dataset_path_output, sep=';')
# Out:
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '7:49 PM · Sep 9, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '11:47 AM · Sep 2, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '11:03 AM · Sep 3, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:12 AM · Sep 10, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '3:10 PM · Sep 1, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '11:24 AM · Sep 3, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:49 PM · Sep 13, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '4:26 PM · Sep 4, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '12:53 PM · Sep 2, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '5:22 PM · Sep 2, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:14 AM · Sep 3, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:49 AM · Sep 5, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '6:34 PM · Sep 1, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:13 AM · Sep 3, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '8:37 PM · Sep 1, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '1:25 PM · Aug 30, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '5:44 PM · Sep 3, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '8:56 PM · Sep 1, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '8:54 AM · Sep 4, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '2:35 PM · Sep 9, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:52 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:32 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:30 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:25 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:22 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:00 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '8:58 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '8:53 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '8:48 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '8:47 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '3:35 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '8:26 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '8:17 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '7:18 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '7:15 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '7:00 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:25 AM · Sep 15, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '11:41 AM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '12:07 AM · Sep 15, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '8:44 AM · Sep 15, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '11:06 PM · Sep 15, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '6:03 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:45 AM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '11:52 AM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:24 AM · Jan 14, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:16 AM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '12:06 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:31 PM · Sep 15, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:53 PM · Sep 15, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '4:00 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '4:51 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '4:31 PM · Jan 15, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '8:05 AM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:29 PM · Sep 15, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '1:27 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '12:19 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:37 AM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:56 PM · Sep 15, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:50 PM · Sep 15, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:46 PM · Sep 15, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '6:52 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:44 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:13 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:40 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:58 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:11 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:40 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:03 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '11:10 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:08 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '9:41 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '1:49 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:35 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:01 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:19 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '11:46 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '2:37 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '11:54 PM · Sep 16, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:33 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# Failed format: %I:%M:%S %p · %b %d, %Y
# Error: time data '10:27 AM · Sep 17, 2024' does not match format '%I:%M:%S %p · %b %d, %Y'
# Successful format: %I:%M %p · %b %d, %Y
# 0    2024-09-09 19:49:00
# 1    2024-09-02 11:47:00
# 2    2024-09-03 11:03:00
# 3    2024-09-10 09:12:00
# 4    2024-09-01 15:10:00
#              ...
# 75   2024-09-16 23:46:00
# 76   2024-09-17 02:37:00
# 77   2024-09-16 23:54:00
# 78   2024-09-17 10:33:00
# 79   2024-09-17 10:27:00
# Name: date, Length: 80, dtype: datetime64[ns]
